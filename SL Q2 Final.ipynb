# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/ 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
import selenium
import pandas as pd
from selenium import webdriver

driver = webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32/chromedriver.exe")

driver.get('https://www.naukri.com/')

search_job=driver.find_element_by_id('qsb-keyword-sugg')
search_job.send_keys("Data Scientist")
search_loc=driver.find_element_by_xpath("//input[@id='qsb-location-sugg']")
search_loc.send_keys("Bangalore/Bengaluru")



url="https://www.naukri.com/data-scientist-jobs-in-bangalore-bengaluru?k=data%20scientist&l=bangalore%2Fbengaluru"

driver.get(url)

job_titles=[]
company_names=[]
locations_list=[]


titles_tags=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
titles_tags[0:4]

for i in titles_tags:
    title=i.text
    job_titles.append(title)
job_titles[0:4]

companies_tags=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
companies_tags[0:4]


for i in companies_tags:
    company_name=i.text
    company_names.append(company_name)
company_names[0:4]


locations_tags=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span[1]")
locations_tags[0:4]

for i in locations_tags:
    locations=i.text
    locations_list.append(locations)
locations_list[0:4]

(len(job_titles),len(company_names),len(locations_list))

jobs=pd.DataFrame({})
jobs['titles']=job_titles[0:10]
jobs['company']=company_names[0:10]
jobs['location']=locations_list[0:10]

jobs
# Out:
# <ipython-input-8-bb469f2ae900>:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32/chromedriver.exe")
# <ipython-input-8-bb469f2ae900>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_job=driver.find_element_by_id('qsb-keyword-sugg')
# <ipython-input-8-bb469f2ae900>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_loc=driver.find_element_by_xpath("//input[@id='qsb-location-sugg']")
# <ipython-input-8-bb469f2ae900>:25: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   titles_tags=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
# <ipython-input-8-bb469f2ae900>:33: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   companies_tags=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
# <ipython-input-8-bb469f2ae900>:43: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   locations_tags=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span[1]")
#                                               titles  \
# 0                                     Data Scientist
# 1                                     Data Scientist
# 2  Senior Data Scientist | Fortune 500 Supermarke...
# 3                              Senior Data Scientist
# 4                                     Data Scientist
# 5  Hiring For AI Architect / Lead Data Scientist ...
# 6                      Lead Data Scientist, Presales
# 7                              Senior Data Scientist
# 8                       Senior / Lead Data Scientist
# 9  Lead Data Scientist - Machine Learning/ Data M...
#
#                                   company  \
# 0                                  Amazon
# 1             Alstom Transport India Ltd.
# 2  TALENT500 TECH (INDIA) PRIVATE LIMITED
# 3                             Santechture
# 4                             Evalueserve
# 5                 IQVIA RDS India Pvt Ltd
# 6                               Moveworks
# 7                            Easy Recruit
# 8                              Bukuwarung
# 9            Wrackle Technologies Pvt Ltd
#
#                                             location
# 0  Hyderabad/Secunderabad, Pune, Bangalore/Bengaluru
# 1                                Bangalore/Bengaluru
# 2                                Bangalore/Bengaluru
# 3  Hyderabad/Secunderabad, Chennai, Bangalore/Ben...
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# 6                                Bangalore/Bengaluru
# 7                                Bangalore/Bengaluru
# 8                                Bangalore/Bengaluru
# 9                                Bangalore/Bengaluru
